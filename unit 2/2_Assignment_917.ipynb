# %% [markdown]
# # Assignment 2: Structured Prompting for Code Generation
#
# ## Objective
# Write a structured prompt to generate a **Python Function** based on specific criteria.
#
# ### Requirements:
# - **Context:** Senior Python Developer.
# - **Objective:** Write a function to reverse a string.
# - **Constraint:** Use recursion (no slicing `[::-1]`).
# - **Style:** Include detailed docstrings.

# %%
print("Name: Mohithkumar M S")
print("SRN: PES2UG23CS917")
# Out:
# Name: Mohithkumar M S
# SRN: PES2UG23CS917

# %%
pip install langchain_google_genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 3.5 MB/s eta 0:00:00
# ...

# %%
from dotenv import load_dotenv
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Load environment variables
load_dotenv()

# Initialize LLM (using low temperature for precise code generation)
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.0, google_api_key="AIzaSyCuVLeHGhk4U8dbjyEkK9Xtil_TPUX699Q")

# Structured Prompt using CO-STAR principles
structured_prompt = """
# Context
You are a Senior Python Developer with a focus on writing clean, efficient, and well-documented code.

# Objective
Create a Python function that reverses a given string.

# Constraints
1. You MUST use recursion to solve this problem.
2. You are NOT allowed to use string slicing like `[::-1]` for the reversal logic.
3. Handle the base case for an empty string or a single-character string.
4. Ensure the function works correctly with empty inputs.

# Style
1. Follow PEP 8 guidelines.
2. Include a Google-style or ReST-style detailed docstring that explains the parameters, return value, and the recursive logic used.
3. Use type hinting for the input and output.

# Output Format
Provide only the Python code for the function, including necessary imports if any (though none should be needed for this task).
"""

# Define the chain
chain = ChatPromptTemplate.from_template(structured_prompt) | llm | StrOutputParser()

# Execute and display
print(chain.invoke({}))
# Out:
# ```python
# def reverse_string(s: str) -> str:
#     """Reverses a given string using recursion.
#
#     This function takes a string and reverses it by recursively calling itself
#     with a substring that excludes the first character, and then appending
#     the first character of the original string to the result of that recursive call.
#
#     Args:
#         s: The input string to be reversed.
#
#     Returns:
#         The reversed string.
#
#     Examples:
#         >>> reverse_string("hello")
#         'olleh'
#         >>> reverse_string("Python")
#         'nohtyP'
#         >>> reverse_string("")
#         ''
#         >>> reverse_string("a")
#         'a'
#     """
#     # Base case: If the string is empty or has only one character, it's already reversed.
#     if len(s) <= 1:
#         return s
#     # Recursive step:
#     # Take the first character (s[0]) and append it to the result of
#     # reversing the rest of the string (s[1:]).
# ...
