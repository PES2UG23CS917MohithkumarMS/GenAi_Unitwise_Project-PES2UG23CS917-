# %% [markdown]
# # Assignment Solution: Movie Age Calculator
#
# This notebook contains the solution to the assignment in `1_LangChain_Foundation.ipynb`.
#
# ## Assignment Requirement:
# Create a chain that:
# 1. Takes a movie name.
# 2. Asks for its release year.
# 3. Calculates how many years ago that was.
#
# **Constraint:** One line of LCEL.

# %%
print("Name: Mohithkumar M S")
print("SRN: PES2UG23CS917")
# Out:
# Name: Mohithkumar M S
# SRN: PES2UG23CS917

# %%
pip install langchain_google_genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# Imports
from dotenv import load_dotenv
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# Setup
# Load environment variables
load_dotenv()

# Set your Google API Key here (replace "YOUR_API_KEY" with your actual key)
os.environ["GOOGLE_API_KEY"] = "AIzaSyCuVLeHGhk4U8dbjyEkK9Xtil_TPUX699Q"

# Initialize LLM
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
# The One-Line LCEL Chain
chain = ChatPromptTemplate.from_template("The movie {movie_name} was released in {release_year}. Calculate how many years ago that was from the current year (2026).") | llm | StrOutputParser()

# Test the chain
result = chain.invoke({"movie_name": "Zindagi Na Milegi Dobara", "release_year": "2011"})
print(result)
# Out:
# The movie Zindagi Na Milegi Dobara was released **15 years ago** from 2026.
#
# Here's the calculation:
# 2026 - 2011 = 15 years
